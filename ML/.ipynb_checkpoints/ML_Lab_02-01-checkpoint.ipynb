# %%
import tensorflow as tf

# %%
x_train = [1,2,3]

# %%
y_train = [1,2,3]

# %%
W = tf.Variable(initial_value=tf.random_normal(shape=[1]), name='Weight')

# %%
b = tf.Variable(initial_value=tf.random_normal(shape=[1]), name='bias')

# %%
hypothesis = x_train * W + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

# %%
train = optimizer.minimize(cost)

# %%
sess = tf.Session()

# %%
sess.run(tf.global_variables_initializer())

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 2.7975493e-06 [0.99805737] [0.00441604]
# 20 2.5408838e-06 [0.9981487] [0.00420851]
# 40 2.3077707e-06 [0.99823564] [0.00401073]
# 60 2.095848e-06 [0.99831855] [0.00382225]
# 80 1.90359e-06 [0.9983976] [0.00364264]
# 100 1.72889e-06 [0.99847287] [0.00347146]
# 120 1.5702649e-06 [0.99854463] [0.00330834]
# 140 1.426118e-06 [0.99861294] [0.0031529]
# 160 1.2951872e-06 [0.99867815] [0.00300477]
# 180 1.1762869e-06 [0.99874026] [0.0028636]
# 200 1.0684648e-06 [0.9987995] [0.00272905]
# 220 9.703334e-07 [0.9988558] [0.00260082]
# 240 8.8127166e-07 [0.9989096] [0.00247862]
# 260 8.004259e-07 [0.9989608] [0.00236218]
# 280 7.270428e-07 [0.99900967] [0.00225119]
# 300 6.603887e-07 [0.9990562] [0.0021454]
# 320 5.997044e-07 [0.99910057] [0.00204459]
# 340 5.446661e-07 [0.9991428] [0.00194853]
# 360 4.946935e-07 [0.99918306] [0.00185696]
# 380 4.492828e-07 [0.9992215] [0.00176971]
# 400 4.080711e-07 [0.99925804] [0.00168656]
# 420 3.7053596e-07 [0.99929297] [0.00160731]
# 440 3.3666865e-07 [0.9993261] [0.00153178]
# 460 3.056666e-07 [0.99935776] [0.00145983]
# 480 2.7771637e-07 [0.9993879] [0.00139127]
# 500 2.522345e-07 [0.99941677] [0.00132591]
# 520 2.2902965e-07 [0.9994441] [0.00126365]
# 540 2.0810653e-07 [0.9994702] [0.0012043]
# 560 1.8900198e-07 [0.9994951] [0.00114776]
# 580 1.7162961e-07 [0.9995188] [0.00109385]
# 600 1.559089e-07 [0.99954146] [0.0010425]
# 620 1.416433e-07 [0.9995629] [0.00099355]
# 640 1.2859128e-07 [0.99958336] [0.00094691]
# 660 1.16857564e-07 [0.99960285] [0.00090245]
# 680 1.0614398e-07 [0.99962157] [0.00086009]
# 700 9.640869e-08 [0.9996394] [0.00081974]
# 720 8.757818e-08 [0.9996562] [0.00078128]
# 740 7.95737e-08 [0.99967235] [0.00074458]
# 760 7.225028e-08 [0.99968785] [0.00070966]
# 780 6.561523e-08 [0.9997023] [0.00067637]
# 800 5.96066e-08 [0.9997164] [0.00064465]
# 820 5.419084e-08 [0.9997296] [0.00061444]
# 840 4.9204065e-08 [0.9997423] [0.00058559]
# 860 4.472027e-08 [0.99975437] [0.00055815]
# 880 4.0575653e-08 [0.999766] [0.00053192]
# 900 3.6890057e-08 [0.9997768] [0.00050701]
